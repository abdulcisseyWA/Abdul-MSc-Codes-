# %%
#import libraries
import momepy as mm
import geopandas as gpd
import matplotlib.pyplot as plt 
import pandas as pd 
import os 
import libpysal
import numpy as np
import shapely
import mapclassify
import seaborn as sns
from matplotlib.lines import Line2D
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
path_1 = '/home/jovyan/private/Thesis/nai_train_data/'

# %%
save_path = '/home/jovyan/private/Thesis/Boxplots/'

# %%
# train_data = gpd.read_file(path_1 + 'train_dataV4.shp')


# test_data = gpd.read_file(path_1 + 'test_dataV4.shp')

# %%
combined_data = gpd.read_file(path_1 + 'Nairobi_train_test_dataV4.shp')

# %%
# train_data.plot(), test_data.plot()

# %%
combined_data.plot()
# Out:
# <AxesSubplot: >

# %%
# #check columns of all dataframes
# for col in train_data.columns:
#     print(col)

# %%
# #check columns of all dataframes
# for col in test_data.columns:
#     print(col)

# %%
# # Assuming 'gdf' is your GeoDataFrame
# # formal_grids = data[data['class'] == 0]
# # slum_grids = data[data['class'] == 1]

# # Plot formal grids in blue and slum grids in red
# fig, ax = plt.subplots(figsize=(10, 8))  # Set the figure size here

# train_data.plot(ax=ax, color='blue')
# test_data.plot(ax=ax, color='red')

# # Remove x and y ticks
# ax.set_xticks([])
# ax.set_yticks([])

# # Create custom legend handles
# legend_handles = [
#     Line2D([0], [0], marker='o', color='w', label='Formal Grids',
#            markerfacecolor='blue', markersize=10),
#     Line2D([0], [0], marker='o', color='w', label='Slum Grids',
#            markerfacecolor='red', markersize=10)
# ]

# # Add the custom legend to the plot
# ax.legend(handles=legend_handles, loc='lower right')

# plt.title('Nairobi Training Data Per Class')

# # plt.savefig(save_path + 'accra_ROI_allgrids_prediction_model_4.png')

# # Show the plot
# plt.show()

# %% [markdown]
# ## nairobi

# %%
# # Combine the dataframes
# combined_data = pd.concat([train_data, test_data], ignore_index=True)
# combined_data.shape

# %%
# combined_data.to_file(path_1 + 'Nairobi_train_test_dataV4.shp')

# %%
#check columns of all dataframes
for col in combined_data.columns:
    print(col)
# Out:
# ORIG_FID
# Dist_ATM
# Dist_Banks
# Dist_Clin
# Dist_Col
# Dist_ComC
# Dist_Dump
# Dist_Hosp
# Dist_Indus
# Dist_Kind
# Dist_Marke
# Dist_PlayG
# Dist_Polic
# Dist_Resta
# Dist_River
# Dist_Sch
# Dist_Uni
# NDVI
# ZonalSt_Sl
# building_c
# height_m
# bArea_m
# bVol_m
# bPer_m
# bCoA_m
# bFoF_m
# bVFR_m
# bCCo_m
# bCor_m
# bSqu_m
# bERI_m
# bElo_m
# ssbCCM_m
# ssbCCD_m
# mtbSWR_m
# bOri_m
# mtbAli_m
# mtbNDi_m
# libNCo_m
# ldbPWL_m
# ltbIBD_m
# ltcBuA_m
# stbSAl_m
# tcOri_m
# sdcLAL_m
# sdcArea_m
# sscCCo_m
# sscERI_m
# mtcWNe_m
# mdcAre_m
# licGDe_m
# ltcWRB_m
# sicCAR_m
# sicFAR_m
# stcSAl_m
# ldkAre_m
# ldkPer_m
# lskCCo_m
# lskERI_m
# lskCWA_m
# ltkOri_m
# ltkWNB_m
# likWBB_m
# sdsLen_m
# sdsSPW_m
# sdsSPH_m
# sdsSPR_m
# sdsSPO_m
# sdsSWD_m
# sdsSHD_m
# sssLin_m
# sdsAre_m
# sisBpM_m
# misRea_m
# mdsAre_m
# ldsMSL_m
# ldsRea_m
# mtdDeg_m
# lcdMes_m
# linP3W_m
# linP4W_m
# linPDE_m
# lcnClo_m
# ldsCDL_m
# xcnSCl_m
# mtdMDi_m
# lddNDe_m
# linWID_m
# lddRea_m
# lddARe_m
# sddAre_m
# ...

# %%
from matplotlib.lines import Line2D

# Assuming 'gdf' is your GeoDataFrame
formal_grids = combined_data[combined_data['class'] == 0]
slum_grids = combined_data[combined_data['class'] == 1]

# Plot formal grids in blue and slum grids in red
fig, ax = plt.subplots(figsize=(10, 8))  # Set the figure size here

formal_grids.plot(ax=ax, color='blue')
slum_grids.plot(ax=ax, color='red')

# Remove x and y ticks
ax.set_xticks([])
ax.set_yticks([])

# Create custom legend handles
legend_handles = [
    Line2D([0], [0], marker='o', color='w', label='Formal Grids',
           markerfacecolor='blue', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Slum Grids',
           markerfacecolor='red', markersize=10)
]

# Add the custom legend to the plot
ax.legend(handles=legend_handles, loc='lower right')

plt.title('Nairobi Training Data Per Class')

# plt.savefig(save_path + 'accra_ROI_allgrids_prediction_model_4.png')

# Show the plot
plt.show()

# %%
predictors = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
            'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m'
]

# %%
top_20_features = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
                   'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m',
                   'sdcLAL_m','sicFAR_m','licGDe_m','Dist_Dump','midRea_m',
                   'sdcArea_Sh','bArea_Gini','ltcWRB_m','sdsSPO_m','sdsSPW_m']

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x2 subplots
fig, axes = plt.subplots(5, 2, figsize=(10, 10))  # Adjust the size as needed

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Dictionary mapping short names to full descriptions
full_names = {
    'sdcArea_m': 'Area of a Tessellation Cell',
    'ltbIBD_m': 'Mean Inter-building Distance',
    'building_c': 'Building Count',
    'mdcAre_m': 'Area Covered by Neighbouring Cells',
    'sdcArea_Si': 'Diversity of Tess. Cell Area',
    'blg_densit': 'Building Density',
    'sicCAR_m': 'Covered Area Ratio',
    'mtcWNe_m': 'Weighted Neighbours of a Tess. Cell',
    'Dist_Sch': 'Distance to School',
    'sdcLAL_m': 'Longest Axis Length'
}

# List of your predictor variable names
predictors = list(full_names.keys())

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(predictors):
    sns.boxplot(x='class', y=predictor, data=combined_data, ax=axes[i], palette=['blue', 'red'], showfliers=False)
    axes[i].set_title(full_names[predictor], fontsize=12)
    
   # Remove x-axis labels for the first four rows
    if i < len(predictors) - 2:
        axes[i].set_xticklabels([])
        axes[i].set_xlabel('')  # Remove x-axis label
        
    # Set x-axis label only for the last row of subplots
    if i >= len(predictors) - 2:
        axes[i].set_xticklabels(['Formal Areas', 'Slums'], fontsize=12)
        axes[i].set_xlabel('Class Labels', fontsize=16)
    # else:
    #     axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Save the plot to a file
plt.savefig(save_path + 'boxplot_of_predictors_by_class_Nairobi2.png', dpi=300)
# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(7, 3, figsize=(10, 10))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

top_20_features = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
                   'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m',
                   'sdcLAL_m','sicFAR_m','licGDe_m','Dist_Dump','midRea_m',
                   'sdcArea_Sh','bArea_Gini','ltcWRB_m','sdsSPO_m','sdsSPW_m']

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(top_20_features):
    sns.boxplot(x='class', y= predictor, data=combined_data, ax=axes[i], palette=['blue', 'red'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    axes[i].set_xlabel('')  # Remove x-axis label
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %% [markdown]
# ## do same for accra

# %%
path_3 = '/home/jovyan/private/Thesis/Accra/Acc_train_data/'
acc_data = gpd.read_file(path_3 + 'acc_train_data2.shp')

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(5, 2, figsize=(10, 10))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
predictors = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
            'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m'
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(predictors):
    sns.boxplot(x='class', y=predictor, data=acc_data, ax=axes[i], palette=['blue', 'red'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    axes[i].set_xlabel('')  # Remove x-axis label
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x2 subplots
fig, axes = plt.subplots(5, 2, figsize=(10, 10))  # Adjust the size as needed

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Dictionary mapping short names to full descriptions
full_names = {
    'sdcArea_m': 'Area of a Tessellation Cell',
    'ltbIBD_m': 'Mean Inter-building Distance',
    'building_c': 'Building Count',
    'mdcAre_m': 'Area Covered by Neighbouring Cells',
    'sdcArea_Si': 'Diversity of Tess. Cell Area',
    'blg_densit': 'Building Density',
    'sicCAR_m': 'Covered Area Ratio',
    'mtcWNe_m': 'Weighted Neighbours of a Tess. Cell',
    'Dist_Sch': 'Distance to School',
    'sdcLAL_m': 'Longest Axis Length'
}

# List of your predictor variable names
predictors = list(full_names.keys())

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(predictors):
    sns.boxplot(x='class', y=predictor, data=acc_data, ax=axes[i], palette=['blue', 'red'], showfliers=False)
    axes[i].set_title(full_names[predictor], fontsize=12)
    
   # Remove x-axis labels for the first four rows
    if i < len(predictors) - 2:
        axes[i].set_xticklabels([])
        axes[i].set_xlabel('')  # Remove x-axis label
        
    # Set x-axis label only for the last row of subplots
    if i >= len(predictors) - 2:
        axes[i].set_xticklabels(['Formal Areas', 'Slums'], fontsize=12)
        axes[i].set_xlabel('Class Labels', fontsize=16)
    # else:
    #     axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Save the plot to a file
plt.savefig(save_path + 'boxplot_of_predictors_by_class_Accra2.png', dpi=300)
# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(7, 3, figsize=(10, 10))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

top_20_features = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
                   'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m',
                   'sdcLAL_m','sicFAR_m','licGDe_m','Dist_Dump','midRea_m',
                   'sdcArea_Sh','bArea_Gini','ltcWRB_m','sdsSPO_m','sdsSPW_m']

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(top_20_features):
    sns.boxplot(x='class', y= predictor, data=acc_data, ax=axes[i], palette=['blue', 'red'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    axes[i].set_xlabel('')  # Remove x-axis label
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
acc_data.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## do same to iunderstand the clusters output

# %%
#save the slum train grids
path_4 = '/home/jovyan/private/Thesis/Clustering/nai_formal_grids_w_clusters.shapefile/'
cluster_data = gpd.read_file(path_4 + 'nai_formal_grids_w_clusters.shp')

# %%
cluster_data.plot()
# Out:
# <AxesSubplot: >

# %%
gdf = cluster_data
gdf.plot()
# Out:
# <AxesSubplot: >

# %%
# Assuming you have a dataframe called 'df'
column_mapping = {
    "sdcArea_x_": "sdcArea_m",
    "mtcWNe_x_m": "mtcWNe_m",
    "mdcAre_x_m": "mdcAre_m",
    "sicCAR_x_m": "sicCAR_m",
}

# Use the 'rename' method to update the column names
cluster_data.rename(columns=column_mapping, inplace=True)

# %%
# Assuming you have a dataframe called 'df'
column_mapping = {
    "sdcLAL_x_m": "sdcLAL_m",
    "sicFAR_x_m": "sicFAR_m",
    "licGDe_x_m": "licGDe_m",
    "sicCAR_x_m": "sicCAR_m",
}

# Use the 'rename' method to update the column names
cluster_data.rename(columns=column_mapping, inplace=True)

# %%
# 'sdcLAL_m','sicFAR_m','licGDe_m','Dist_Dump','midRea_m',
#                    'sdcArea_Sh','bArea_Gini','ltcWRB_m','sdsSPO_m','sdsSPW_m'

# %%
#check columns of all dataframes
for col in cluster_data.columns:
    print(col)
# Out:
# ORIG_FID
# Dist_ATM
# Dist_Banks
# Dist_Clin
# Dist_Col
# Dist_ComC
# Dist_Dump
# Dist_Hosp
# Dist_Indus
# Dist_Kind
# Dist_Marke
# Dist_PlayG
# Dist_Polic
# Dist_Resta
# Dist_River
# Dist_Sch
# Dist_Uni
# NDVI
# ZonalSt_Sl
# building_c
# height_m
# area_in_me
# bArea_m
# bVol_m
# bPer_m
# bCoA_m
# bFoF_m
# bVFR_m
# bCCo_m
# bCor_m
# bSqu_m
# bERI_m
# bElo_m
# floor_area
# ssbCCM_m
# ssbCCD_m
# mtbSWR_m
# bOri_m
# mtbAli_m
# mtbNDi_m
# libNCo_m
# ldbPWL_m
# ltbIBD_m
# ltcBuA_m
# stbSAl_m
# nodeID_x_m
# tcOri_x_m
# sdcLAL_m
# sdcArea_m
# sscCCo_x_m
# sscERI_x_m
# mtcWNe_m
# mdcAre_m
# licGDe_m
# ltcWRB_x_m
# sicCAR_m
# sicFAR_m
# stcSAl_x_m
# ldkAre_m
# ldkPer_m
# lskCCo_m
# lskERI_m
# lskCWA_m
# ltkOri_m
# ltkWNB_m
# likWBB_m
# sdsLen_m
# sdsSPW_m
# sdsSPH_m
# sdsSPR_m
# sdsSPO_m
# sdsSWD_m
# sdsSHD_m
# sssLin_m
# sdsAre_m
# sisBpM_m
# misRea_m
# mdsAre_m
# ldsMSL_m
# ldsRea_m
# mtdDeg_m
# lcdMes_m
# proportion
# proporti_1
# proporti_2
# local_clos
# ldsCDL_m
# xcnSCl_m
# mtdMDi_m
# ...

# %%
needed_columns = [
    "bArea_Gini", "bArea_Shan", "bArea_Simp", "bArea_Thei",
    "sdcArea_Gi", "sdcArea_Sh", "sdcArea_Si", "sdcArea_Th",
    "bPer_Gini_", "bPer_Shann", "bPer_Simps", "bPer_Theil",
    "bSqu_Gini_", "bSqu_Shann", "bSqu_Simps", "bSqu_Theil",
    "bERI_Gini_", "bERI_Shann", "bERI_Simps", "bERI_Theil",
    "blg_densit"
]

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(5, 2, figsize=(10, 10))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
predictors = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
            'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m'
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(predictors):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    axes[i].set_xlabel('')  # Remove x-axis label
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(7, 3, figsize=(15, 15))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

top_20_features = ['sdcArea_m','ltbIBD_m','building_c','mdcAre_m','sdcArea_Si',
                   'blg_densit','sicCAR_m','mtcWNe_m','Dist_Sch','mtbNDi_m',
                   'sdcLAL_m','sicFAR_m','licGDe_m','Dist_Dump','midRea_m',
                   'sdcArea_Sh','bArea_Gini','sdsSPO_m','sdsSPW_m']

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(top_20_features):
    sns.boxplot(x='clusters_4', y= predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    axes[i].set_xlabel('')  # Remove x-axis label
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(7, 3, figsize=(15, 15))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
needed_columns = [
    "bArea_Gini", "bArea_Shan", "bArea_Simp", "bArea_Thei",
    "sdcArea_Gi", "sdcArea_Sh", "sdcArea_Si", "sdcArea_Th",
    "bPer_Gini_", "bPer_Shann", "bPer_Simps", "bPer_Theil",
    "bSqu_Gini_", "bSqu_Shann", "bSqu_Simps", "bSqu_Theil",
    "bERI_Gini_", "bERI_Shann", "bERI_Simps", "bERI_Theil",
    "blg_densit"
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(needed_columns):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    
   # Set x-axis label only for the last row of subplots
    if i >= len(needed_columns) - 3:
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    else:
        axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(4, 3, figsize=(10, 10))  # Adjust the size as needed
fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
needed_columns = [
    "bArea_Gini",  "bArea_Simp", 
    "sdcArea_Gi",  "sdcArea_Si", 
    "bPer_Gini_",  "bPer_Simps", 
    "bSqu_Gini_",  "bSqu_Simps", 
    "bERI_Gini_",  "bERI_Simps", 
    "blg_densit"
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(needed_columns):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    
   # Set x-axis label only for the last row of subplots
    if i >= len(needed_columns) - 3:
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    else:
        axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plot
plt.show()

# %%
# NDVI
# ZonalSt_Sl
# building_c
# height_m

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x4 subplots
fig, axes = plt.subplots(3, 3, figsize=(20, 20))  # Adjust the size as needed
# fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
needed_columns = [
    "bArea_Gini",  "NDVI", 
    "sdcArea_Gi",  "bArea_m", 
    "bPer_Gini_",  "height_m", 
    "bSqu_Gini_",  
    "bERI_Gini_",  
    "blg_densit"
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(needed_columns):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['red', 'blue', 'green', 'purple'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    
   # Set x-axis label only for the last row of subplots
    if i >= len(needed_columns) - 3:
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    else:
        axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# Save the plot to a file
plt.savefig(save_path + 'boxplot_of_predictors_by_class.png', dpi=300)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'cluster_data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 4x3 subplots
fig, axes = plt.subplots(4, 3, figsize=(20, 20), constrained_layout=True)
# fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
needed_columns = [
    "bArea_Gini",  "bArea_Simp", 
    "sdcArea_Gi",  "sdcArea_Si", 
    "bPer_Gini_",  "bPer_Simps", 
    "bSqu_Gini_",  "bSqu_Simps", 
    "bERI_Gini_",  "bERI_Simps", 
    "blg_densit"
]

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(needed_columns):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    
    # Set x-axis label only for the last row of subplots
    if i // 3 == 3:  # Adjust the condition based on the number of columns
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    else:
        axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Hide the empty subplot (if there's any)
for i in range(len(needed_columns), len(axes)):
    axes[i].set_visible(False)

# Save the plot to a file
# plt.savefig('boxplot_of_predictors_by_class.png', dpi=300)

# Optionally display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'cluster_data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 4x3 subplots
fig, axes = plt.subplots(3, 3, figsize=(20, 20), constrained_layout=True)
# fig.suptitle('Boxplot of Predictors by Class', fontsize=16)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of your predictor variable names
needed_columns = [
    "bArea_Gini",  "NDVI", 
    "sdcArea_Gi",  "bArea_m", 
    "bPer_Gini_",  "height_m", 
    "bSqu_Gini_",  
    "bERI_Gini_",  
    "blg_densit"
]


# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(needed_columns):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(predictor, fontsize=12)
    
    # Set x-axis label only for the last row of subplots
    if i // 3 == 3:  # Adjust the condition based on the number of columns
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    else:
        axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label

# Hide the empty subplot (if there's any)
for i in range(len(needed_columns), len(axes)):
    axes[i].set_visible(False)

# Save the plot to a file
# plt.savefig('boxplot_of_predictors_by_class.png', dpi=300)

# Optionally display the plot
plt.show()

# %%
# Assuming 'data' is your DataFrame and it contains the listed predictor variables.

# Set the style of the visualization
sns.set_style('whitegrid')

# Create a figure with a grid of 5x2 subplots
fig, axes = plt.subplots(5, 2, figsize=(10, 10))  # Adjust the size as needed

# Flatten the axes array for easy iteration
axes = axes.flatten()


# Dictionary mapping short names to full descriptions
full_names = {
    'bArea_Gini': 'Area of Building',
    'sdcArea_Gi': 'Area of Tessellation Cell',
    'bPer_Gini_': 'Preimeter of Building ',
    'bSqu_Gini_': 'Building Squadness',
    'bERI_Gini_': 'Building Irregularity',
    'blg_densit': 'Building Density',
    'NDVI': 'NDVI',
    'bArea_m': 'Building Area',
    'height_m': 'Building Height',
   
}

# List of your predictor variable names
predictors = list(full_names.keys())

# Loop through the predictors and create a boxplot for each
for i, predictor in enumerate(predictors):
    sns.boxplot(x='clusters_4', y=predictor, data=cluster_data, ax=axes[i], palette=['blue', 'red', 'green', 'orange'], showfliers=False)
    axes[i].set_title(full_names[predictor], fontsize=12)
    
   # Remove x-axis labels for the first four rows
    if i < len(predictors) - 2:
        axes[i].set_xticklabels([])
        axes[i].set_xlabel('')  # Remove x-axis label
        
    # Set x-axis label only for the last row of subplots
    if i >= len(predictors) - 2:
        axes[i].set_xticklabels(['0', '1', '2', '3'], fontsize=12)
        axes[i].set_xlabel('Cluster Labels', fontsize=16)
    # else:
    #     axes[i].set_xlabel('')  # Remove x-axis label for other subplots
    
    axes[i].set_ylabel('')  # Remove y-axis label
    
# Hide the empty subplot (if there's any)
for i in range(len(predictors), len(axes)):
    axes[i].set_visible(False)

# Adjust the layout so titles and labels don't overlap
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Save the plot to a file
plt.savefig(save_path + 'boxplot_of_predictors_by_clusters.png', dpi=300)
# Show the plot
plt.show()
